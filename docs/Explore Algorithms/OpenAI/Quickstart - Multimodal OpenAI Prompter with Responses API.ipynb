# %% [markdown]
# # Quickstart: Multimodal OpenAI Prompter with Responses API

# %% [markdown]
# Use OpenAI's Responses API to enrich your data with multimodal content such as PDFs, images, and documents. This quickstart shows how to use `OpenAIPrompt` with Spark DataFrame columns that contain file paths, HTTP(S) URLs, or base64-encoded data URLs.

# %% [markdown]
# ## Prerequisites
# - An active Spark session (`spark`)
# - Access to an OpenAI resource with the Responses API enabled. Deployment should be a multimodal model.
# - At least one image, PDF, or text file that you want the model to analyze.

# %% [markdown]
# ## Fill in service information
#
# Next, edit the cell in the notebook to point to your service. In particular set the `service_name`, `deployment_name`, `location`, and `key` variables to match them to your OpenAI service:

# %%
from synapse.ml.core.platform import find_secret

# Fill in the following lines with your service information
# Learn more about selecting which embedding model to choose: https://openai.com/blog/new-and-improved-embedding-model
service_name = "synapseml-openai-3"
deployment_name = "gpt-5.1"
api_version = (
    "2025-04-01-preview"  # Responses API is only supported in this version and later
)

key = find_secret(
    secret_name="openai-api-key-3", keyvault="mmlspark-build-keys"
)  # please replace this line with your key as a string

assert key is not None and service_name is not None

# %% [markdown]
# ## Build a multimodal dataset
# Each row combines a natural-language question with one attachment. The examples below use HTTP(S) image, PDF, and text URLs plus an inline base64 data URL. To read from Lakehouse, ADLS, or another Spark-accessible file system, replace an attachment value with a Hadoop-compatible path such as `abfss://container@account.dfs.core.windows.net/Files/report.pdf`.

# %%
inline_image_url = (
    "data:image/png;base64,"
    "iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAQAAAC1HAwCAAAAC0lEQVR42mP8/x8AAusB9Y9Zl1sAAAAASUVORK5CYII="
)

qa_df = spark.createDataFrame(
    [
        (
            "What's in the image?",
            "https://mmlspark.blob.core.windows.net/datasets/OCR/test2.png",
        ),
        (
            "Summarize this document.",
            "https://mmlspark.blob.core.windows.net/datasets/OCR/paper.pdf",
        ),
        (
            "What are the related works to SynapseML?",
            "https://mmlspark.blob.core.windows.net/publicwasb/Overview.md",
        ),
        (
            "Describe this inline image.",
            inline_image_url,
        ),
    ]
).toDF("questions", "attachments")

# %% [markdown]
# ## Configure `OpenAIPrompt` for file-aware responses
# Any column declared as `path` is treated as an attachment. `OpenAIPrompt` reads the value, detects its content type, and adds the appropriate Responses API content part. Set `fileSizeLimitMB` to reject oversized attachments with a row-level error instead of failing the Spark job.
#
# > **Spark AI Functions implementation note:** SynapseML's internal Spark AI Functions use this `OpenAIPrompt` Responses path. For image path, URL, or data-URL columns, `OpenAIPrompt` sends an `input_image` part with a base64 data URL. It does not pass nested low-level message structs to `OpenAIResponses`. Direct `OpenAIResponses` users can instead provide `Array[Struct]` content parts such as `input_text`, `input_image`, and `input_file`.

# %%
from synapse.ml.services.openai import OpenAIPrompt

prompt_template = "{questions}: {attachments}"

prompter = (
    OpenAIPrompt()
    .setSubscriptionKey(key)
    .setDeploymentName(deployment_name)
    .setCustomServiceName(service_name)
    .setApiVersion(api_version)
    .setApiType(
        "responses"
    )  # We need to use the Responses API, instead of Chat Completions API.
    .setPromptTemplate(prompt_template)
    .setColumnTypes(
        {"attachments": "path"}
    )  # Treat every value in the attachment column as a file source
    .setFileSizeLimitMB(10.0)
    .setErrorCol("error")
    .setOutputCol("outputCol")
)

# %% [markdown]
# ## Generate multimodal responses
# Run the transformer and inspect the question, attachment reference, generated response, and row-level error together. A successful row has a populated `outputCol` and a null `error`.

# %%
responses_df = prompter.transform(qa_df)

responses_df.select(
    "questions",
    "attachments",
    "outputCol",
    "error",
).show(truncate=False)

# %% [markdown]
# ## Next: add Responses tools
#
# `OpenAIPrompt` also supports trusted Responses tool definitions and opt-in structured `toolCallsCol` / `responseStructCol` outputs. SynapseML transports calls but never executes them. See **Quickstart - OpenAI Responses Tool Calling** for argument validation, external resolution, checkpointing, and continuation.

# %%
weather_tool = {
    "type": "function",
    "name": "get_weather",
    "description": "Get weather for a city.",
    "parameters": {
        "type": "object",
        "properties": {"city": {"type": "string"}},
        "required": ["city"],
        "additionalProperties": False,
    },
    "strict": True,
}

tool_prompter = (
    OpenAIPrompt()
    .setSubscriptionKey(key)
    .setDeploymentName(deployment_name)
    .setCustomServiceName(service_name)
    .setApiVersion(api_version)
    .setApiType("responses")
    .setPromptTemplate("What is the weather in {questions}?")
    .setTools([weather_tool])
    .setToolChoice("auto")
    .setToolCallsCol("tool_calls")
    .setResponseStructCol("response_struct")
)
